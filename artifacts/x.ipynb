# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'F:\netsol_project\task_1\credit_decisioning_risk_assesment\artifacts\train.csv')
df1.head()
# Out:
#    last_fico_range_high  last_fico_range_low  collection_recovery_fee  \
# 0                 689.0                685.0                   0.0000
# 1                 694.0                690.0                   0.0000
# 2                 499.0                  0.0                 132.1488
# 3                 789.0                785.0                   0.0000
# 4                 709.0                705.0                   0.0000
#
#    total_pymnt_inv  int_rate  fico_range_high debt_settlement_flag sub_grade  \
# 0         40544.06     13.99            719.0                    N        C3
# 1         21032.83     11.99            689.0                    N        B5
# 2          5072.42     15.31            714.0                    N        C5
# 3         38615.68     13.98            729.0                    N        C1
# 4         13258.98      6.62            754.0                    N        A2
#
#   grade        term loan_condition  loan_condition_encoded
# ...

# %%
df2 = pd.read_csv(r'F:\netsol_project\task_1\credit_decisioning_risk_assesment\artifacts\test.csv')
df2.head()
# Out:
#    last_fico_range_high  last_fico_range_low  collection_recovery_fee  \
# 0                 769.0                765.0                   0.0000
# 1                 629.0                625.0                   0.0000
# 2                 644.0                640.0                1190.3706
# 3                 734.0                730.0                   0.0000
# 4                 759.0                755.0                   0.0000
#
#    total_pymnt_inv  int_rate  fico_range_high debt_settlement_flag sub_grade  \
# 0         14244.06     11.53            664.0                    N        B5
# 1         16034.44     14.03            674.0                    N        C2
# 2         27886.69     17.27            684.0                    Y        C5
# 3          2095.57     11.49            729.0                    N        B5
# 4         25330.72      6.49            719.0                    N        A2
#
#   grade        term loan_condition  loan_condition_encoded
# ...

# %%
df2.nunique()
# Out:
# last_fico_range_high          72
# last_fico_range_low           71
# collection_recovery_fee     4599
# total_pymnt_inv            35692
# int_rate                     525
# fico_range_high               42
# debt_settlement_flag           2
# sub_grade                     35
# grade                          7
# term                           2
# loan_condition                 2
# loan_condition_encoded         2
# dtype: int64

# %%
df2[['last_fico_range_high',
 'last_fico_range_low',
 'collection_recovery_fee',
 'total_pymnt_inv',
 'int_rate',
 'fico_range_high',
 'debt_settlement_flag',
 'sub_grade',
 'grade',
 'term']]
# Out:
#        last_fico_range_high  last_fico_range_low  collection_recovery_fee  \
# 0                     744.0                740.0                   0.0000
# 1                     574.0                570.0                 288.6228
# 2                     734.0                730.0                   0.0000
# 3                     644.0                640.0                   0.0000
# 4                     594.0                590.0                 372.9600
# ...                     ...                  ...                      ...
# 36699                 644.0                640.0                   0.0000
# 36700                 644.0                640.0                   0.0000
# 36701                 704.0                700.0                   0.0000
# 36702                 529.0                525.0                 185.0958
# 36703                 729.0                725.0                   0.0000
#
#        total_pymnt_inv  int_rate  fico_range_high debt_settlement_flag  \
# ...

# %%
df2.dtypes
# Out:
# last_fico_range_high       float64
# last_fico_range_low        float64
# collection_recovery_fee    float64
# total_pymnt_inv            float64
# int_rate                   float64
# fico_range_high            float64
# debt_settlement_flag        object
# sub_grade                   object
# grade                       object
# term                        object
# loan_condition              object
# loan_condition_encoded       int64
# dtype: object

# %%
df2.isna().sum()
# Out:
# last_fico_range_high       0
# last_fico_range_low        0
# collection_recovery_fee    0
# total_pymnt_inv            0
# int_rate                   0
# fico_range_high            0
# debt_settlement_flag       0
# sub_grade                  0
# grade                      0
# term                       0
# dtype: int64

# %%
df2[['loan_condition']]
# Out:
#       loan_condition
# 0          Good Loan
# 1           Bad Loan
# 2          Good Loan
# 3           Bad Loan
# 4           Bad Loan
# ...              ...
# 36699      Good Loan
# 36700      Good Loan
# 36701      Good Loan
# 36702       Bad Loan
# 36703      Good Loan
#
# [36704 rows x 1 columns]

# %%
df3 = df2[['debt_settlement_flag',
 'sub_grade',
 'grade',
 'term']]

# %%
for column in df3.columns:
    unique_classes = df3[column].unique()
    print(f'Unique Classes in each Feature are: {column}:{unique_classes}')
# Out:
# Unique Classes in each Feature are: debt_settlement_flag:['N' 'Y']
# Unique Classes in each Feature are: sub_grade:['B5' 'C2' 'C5' 'A2' 'C3' 'B4' 'B1' 'A5' 'C1' 'F2' 'A4' 'D4' 'D2' 'C4'
#  'E5' 'B2' 'E4' 'F4' 'E1' 'B3' 'D5' 'E3' 'A1' 'D1' 'F3' 'E2' 'D3' 'F1'
#  'A3' 'G2' 'F5' 'G4' 'G3' 'G1' 'G5']
# Unique Classes in each Feature are: grade:['B' 'C' 'A' 'F' 'D' 'E' 'G']
# Unique Classes in each Feature are: term:[' 36 months' ' 60 months']

# %%
import joblib

# %%
# Using pickle
model = joblib.load(r'F:\netsol_project\task_1\credit_decisioning_risk_assesment\artifacts\model.pkl')

# %%
type(model)
# Out:
# sklearn.linear_model._logistic.LogisticRegression

# %%
dir(model)
# Out:
# ['C',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_predict_proba_lr',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_validate_data',
#  '_validate_params',
# ...

# %%
# Out:
# LogisticRegression()

# %%
hasattr(model,'predict')
# Out:
# True
